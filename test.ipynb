# %%
str = input().replace("1. ", "")
strs = str.split(". ")
strs[-1] = strs[-1].replace(".", '')
strs
# Out:
# ['Изменить дату остановки',
#  'Получить ошибку при изменении даты',
#  'Изменить дату запуска',
#  'Управлять своей задачей',
#  'Уничтожить свою задачу',
#  'Создать свою задачу',
#  'Определить приоритет своей задачи',
#  'Определить название своей задачи',
#  'Определить описание своей задачи',
#  'Определить прикрепление своей задачи к проекту',
#  'Определить прикрепление задачи к себе',
#  'Редактировать свою задачу',
#  'Редактировать приоритет своей задачи',
#  'Редактировать название своей задачи',
#  'Редактировать описание своей задачи',
#  'Редактировать прикрепление своей задачи к своему проекту',
#  'Посмотреть информацию о своей задаче',
#  'Управлять списком своих задач своих проектов',
#  'Посмотреть список своих задач своих проектов',
#  'Посмотреть свои задачи отсортированные по приоритету',
#  'Выбрать свою конкретную задачу из списка своих проектов',
#  'Добавить свою задачу в список задач своих проектов',
#  'Удалить задачу из списка задач своих проектов',
# ...

# %%
i = 0
for str in strs:
    i += 1
    # print(f"ID: {i}")
    print(f'Название: {str}.\n')
    print(f'Актор: Сотрудник.\n')
    print(f'Описание: \n')
# Out:
# Название: Изменить дату остановки.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Получить ошибку при изменении даты.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Изменить дату запуска.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Управлять своей задачей.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Уничтожить свою задачу.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Создать свою задачу.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Определить приоритет своей задачи.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Определить название своей задачи.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Определить описание своей задачи.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Определить прикрепление своей задачи к проекту.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Определить прикрепление задачи к себе.
#
# Актор: Сотрудник.
#
# Описание:
#
# Название: Редактировать свою задачу.
#
# Актор: Сотрудник.
#
# Описание:
#
# ...
